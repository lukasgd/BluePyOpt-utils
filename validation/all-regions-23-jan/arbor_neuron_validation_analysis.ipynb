# %% [markdown]
# # Arbor-Neuron validation output analysis

# %%
import re
import json
import pandas
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# Tests with OK status:

# %%
# %%bash
#
# rm tests_{ok,error,na} || true
# grep test_l5pc\ OK l5pc_validate_neuron_arbor_* | tee tests_ok
# Out:
# l5pc_validate_neuron_arbor_all.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00101 (0.05), 1.7e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_all.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000381 (0.05), 2.13e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00275 (0.05), 6.49e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000598 (0.05), 8.77e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00379 (0.05), 2.3e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00104 (0.05), 6.51e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0035 (0.05), 3.45e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_Im_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000982 (0.05), 1.7e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000932 (0.05), 1.41e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000425 (0.05), 1.14e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00201 (0.05), 1.7e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000456 (0.05), 6.74e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00379 (0.05), 4.29e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00135 (0.05), 4.08e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_SKv3_1_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00607 (0.05), 8.47e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Ih_SKv3_1_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00243 (0.05), 0.000355 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00273 (0.05), 1.22e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000622 (0.05), 5.98e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00374 (0.05), 2.25e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000958 (0.05), 9.19e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00357 (0.05), 7.5e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00112 (0.05), 1.82e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_SKv3_1_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00647 (0.05), 1.47e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_Im_SKv3_1_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00211 (0.05), 1.84e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00646 (0.05), 1.33e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0021 (0.05), 1.11e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00208 (0.05), 2.46e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000533 (0.05), 3.01e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00356 (0.05), 3.7e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00116 (0.05), 6.34e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_SKv3_1_NaTs2_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00588 (0.05), 5.06e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_apical_SKv3_1_NaTs2_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00236 (0.05), 2.09e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000936 (0.05), 1.87e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000298 (0.05), 1.02e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00573 (0.05), 9.13e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 1.38e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0477 (0.05), 2.58e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0112 (0.05), 2.72e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0106 (0.05), 1.46e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0103 (0.05), 1.4e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 1.9e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00421 (0.05), 2.22e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00012 (0.05), 8.55e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000127 (0.05), 0.000218 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000182 (0.05), 4.71e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000194 (0.05), 8.26e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00125 (0.05), 4.81e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000532 (0.05), 1.67e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00107 (0.05), 1.82e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000404 (0.05), 3.97e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0058 (0.05), 9.82e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00427 (0.05), 1.61e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000116 (0.05), 4.76e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000123 (0.05), 3.19e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0012 (0.05), 2.24e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000565 (0.05), 4.5e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00492 (0.05), 5.93e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00129 (0.05), 3.6e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00462 (0.05), 1.73e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00228 (0.05), 1.52e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_K_Tst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0063 (0.05), 2.44e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00293 (0.05), 5.47e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0375 (0.05), 0.000341 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00483 (0.05), 2.82e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00122 (0.05), 4.76e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00601 (0.05), 1.89e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00448 (0.05), 1.65e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000207 (0.05), 1.67e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000214 (0.05), 2.65e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00511 (0.05), 2.32e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00147 (0.05), 1.86e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000673 (0.05), 3.6e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000179 (0.05), 4.8e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00582 (0.05), 8.21e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00431 (0.05), 1.63e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.047 (0.05), 2.05e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0103 (0.05), 8.95e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0105 (0.05), 1.83e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0103 (0.05), 1.06e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00418 (0.05), 2.24e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00419 (0.05), 1.72e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000113 (0.05), 1.07e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00012 (0.05), 1.67e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000183 (0.05), 2.16e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000195 (0.05), 1.03e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000799 (0.05), 6.77e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000313 (0.05), 3.35e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0229 (0.05), 2.33e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0225 (0.05), 2.65e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0057 (0.05), 2.05e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00429 (0.05), 1.47e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000125 (0.05), 3.04e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000131 (0.05), 5.48e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.023 (0.05), 3.42e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0225 (0.05), 3.51e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00497 (0.05), 8.77e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00131 (0.05), 6.8e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00466 (0.05), 2.2e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00229 (0.05), 9.87e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_K_Tst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0063 (0.05), 7.75e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00287 (0.05), 2.42e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00492 (0.05), 5.58e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00129 (0.05), 2.06e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0105 (0.05), 3.86e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00882 (0.05), 3.24e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000111 (0.05), 3.11e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000117 (0.05), 7.87e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0161 (0.05), 4.28e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0181 (0.05), 7.26e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.011 (0.05), 1.11e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00814 (0.05), 3.69e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000684 (0.05), 4.08e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000161 (0.05), 4.54e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0071 (0.05), 1.64e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00526 (0.05), 1.45e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000107 (0.05), 1.91e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000805 (0.05), 7.2e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00031 (0.05), 4e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0242 (0.05), 2.48e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0238 (0.05), 4.22e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00398 (0.05), 1.13e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00114 (0.05), 7.75e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000977 (0.05), 3.93e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000276 (0.05), 5.92e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00714 (0.05), 9.37e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00522 (0.05), 1.07e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0484 (0.05), 1.78e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.011 (0.05), 1.03e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0218 (0.05), 3.71e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0214 (0.05), 1.09e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 1.77e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00421 (0.05), 1.56e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000108 (0.05), 4.98e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000115 (0.05), 0.00031 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000178 (0.05), 2.62e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000189 (0.05), 0.000391 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0012 (0.05), 1.37e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000549 (0.05), 4.18e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00735 (0.05), 2.9e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00687 (0.05), 2.24e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00838 (0.05), 6.56e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00661 (0.05), 8.75e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000109 (0.05), 1.26e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000115 (0.05), 5.57e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00455 (0.05), 6.5e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00378 (0.05), 4.94e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00403 (0.05), 5.03e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00112 (0.05), 7.51e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00588 (0.05), 2.55e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00288 (0.05), 5.41e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_K_Tst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00486 (0.05), 1.27e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00231 (0.05), 2.3e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00499 (0.05), 1.26e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00301 (0.05), 6.45e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0266 (0.05), 1.2e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0265 (0.05), 1.35e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00568 (0.05), 1.24e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00416 (0.05), 2.38e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0477 (0.05), 2.11e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0108 (0.05), 0.000106 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0105 (0.05), 6.95e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0103 (0.05), 8.16e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 2.89e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00421 (0.05), 1.93e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 2.08e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00421 (0.05), 1.42e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000116 (0.05), 2.16e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000185 (0.05), 9.99e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000197 (0.05), 1.86e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00125 (0.05), 2.21e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000521 (0.05), 1.9e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000981 (0.05), 2.36e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00032 (0.05), 3.58e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00582 (0.05), 8.07e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00428 (0.05), 3.57e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0479 (0.05), 5e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0111 (0.05), 6.66e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0108 (0.05), 5.41e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0105 (0.05), 5.12e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0042 (0.05), 4.09e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00421 (0.05), 1.58e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000117 (0.05), 2.52e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000123 (0.05), 2.44e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000185 (0.05), 9.44e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000196 (0.05), 8.85e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00124 (0.05), 4.36e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000552 (0.05), 5.89e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00485 (0.05), 9.98e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00467 (0.05), 2.28e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0023 (0.05), 4.58e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0256 (0.05), 2.07e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0256 (0.05), 2.41e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0237 (0.05), 2.53e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00627 (0.05), 3.29e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00287 (0.05), 2.45e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst_K_Pst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00507 (0.05), 1.82e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst_K_Pst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00288 (0.05), 3.93e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00138 (0.05), 6.55e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.
E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00465 (0.05), 1.03e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_CaDynamics_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00117 (0.05), 3.11e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ca_HVA.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0045 (0.05), 1.85e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ca_HVA.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00222 (0.05), 5.86e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ca_LVAst.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00567 (0.05), 3.63e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ca_LVAst.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00441 (0.05), 2.72e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ih.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00472 (0.05), 8.18e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2_Ih.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00125 (0.05), 3.01e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2.ipynb:      "Default dt (0.025): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00482 (0.05), 1.16e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_SKv3_1_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc OK! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00123 (0.05), 9.49e-05 (0.0005).\n"

# %% [markdown]
# Tests with ERROR status:

# %%
# %%bash
#
# grep test_l5pc\ ERROR l5pc_validate_neuron_arbor_* | tee tests_error
# Out:
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0562 (0.05), 2.51e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0562 (0.05), 1.4e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.687 (0.05), 2.86e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.687 (0.05), 2.85e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.559 (0.05), 3.63e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_K_Tst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.561 (0.05), 4.52e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.677 (0.05), 1.72e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SK_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.678 (0.05), 2.26e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000471 (0.05), 0.00297 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000466 (0.05), 0.000891 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_CaDynamics_E2_SKv3_1_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.108 (0.05), 4.93e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0559 (0.05), 6.94e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.056 (0.05), 6.73e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.6 (0.05), 1.58e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.6 (0.05), 1.86e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.249 (0.05), 1.87e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.25 (0.05), 3.91e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.61 (0.05), 1.77e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.61 (0.05), 1.62e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00019 (0.05), 0.0044 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000185 (0.05), 0.00235 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.125 (0.05), 3.5e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_1_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0248 (0.05), 0.00158 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.667 (0.05), 2.74e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.668 (0.05), 2.23e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.581 (0.05), 1.88e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.581 (0.05), 2.17e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000114 (0.05), 0.00216 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0561 (0.05), 2.48e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0562 (0.05), 1.91e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.674 (0.05), 3.95e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.674 (0.05), 3.99e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.541 (0.05), 3.93e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_Tst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.543 (0.05), 4.12e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.669 (0.05), 2.66e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.669 (0.05), 2.77e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00028 (0.05), 0.00556 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000273 (0.05), 0.00232 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.111 (0.05), 2.49e-05 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv3_1_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0396 (0.05), 0.000811 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0559 (0.05), 1.16e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0559 (0.05), 8.9e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0562 (0.05), 5.32e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0562 (0.05), 5.51e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.687 (0.05), 2.83e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.687 (0.05), 2.62e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0572 (0.05), 9.57e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0572 (0.05), 1.26e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.107 (0.05), 3.18e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0809 (0.05), 7.13e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.559 (0.05), 3.67e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_K_Tst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.561 (0.05), 4e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000123 (0.05), 0.00095 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0563 (0.05), 1.3e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0564 (0.05), 1.36e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.681 (0.05), 1.78e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.681 (0.05), 2.14e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.53 (0.05), 5.17e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.532 (0.05), 5.2e-08 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.00124 (0.05), 0.00351 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.064 (0.05), 2e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.14 (0.05), 2.77e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000349 (0.05), 0.0247 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000342 (0.05), 0.00197 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_Et2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000365 (0.05), 0.00875 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_Et2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000352 (0.05), 0.0126 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.116 (0.05), 3.78e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2_Nap_Et2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000332 (0.05), 0.00188 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2_Nap_Et2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.000325 (0.05), 0.00145 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2_NaTa_t.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.121 (0.05), 3.15e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2_NaTa_t.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0295 (0.05), 0.00105 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_CaDynamics_E2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0871 (0.05), 1.66e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_Ca_HVA.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.093 (0.05), 1.31e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_Ca_LVAst.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0788 (0.05), 1.77e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_Ih.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0845 (0.05), 1.56e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0912 (0.05), 9.02e-07 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_SK_E2.ipynb:      "Default dt (0.025): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0929 (0.05), 2.17e-06 (0.0005).\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_SKv3_1_SK_E2.ipynb:      "Fine dt (0.001): test_l5pc ERROR! The mean relative Arbor-Neuron L1-deviation and error (tol in brackets) are 0.0138 (0.05), 0.000775 (0.0005).\n"

# %% [markdown]
# Tests with N/A result:

# %%
# %%bash
#
# touch tests_na
# for f in $(ls l5pc_validate_neuron_arbor_*); do
#     if ! grep test_l5pc\ OK $f > /dev/null && ! grep test_l5pc\ ERROR $f > /dev/null; then
#         echo "$f" | tee -a tests_na
#     fi
# done
# Out:
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst_Ih.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb

# %%
# Read output
with open('tests_ok') as f:
    tests_ok = f.readlines()

with open('tests_error') as f:
    tests_error = f.readlines()

with open('tests_na') as f:
    tests_na = f.readlines()

# %% [markdown]
# Display test results. Test status can be ERROR due to relative L1-norm exceeding the tolerance or, similarly, the quadrature error exceeding a lower threshold.

# %%
def parse_test_status_line(line):
    numeric_vars = ['dt', 'l1_norm', 'l1_tol', 'l1_error', 'l1_error_tol']
    numbers = [r'(?P<{}>[+\-]?\d+[\.]?\d*[eE]?[+\-]?\d*)'.format(name) 
               for name in numeric_vars]
    test_status_pattern = r'^(?P<filename>l5pc_validate_neuron_arbor_\w+.ipynb):\s+\"(?P<dt_setting>Default|Fine) dt \({}\): test_l5pc (?P<test_result>OK|ERROR)! [\w\s-]+\(tol in brackets\) are {} \({}\), {} \({}\)'.format(*numbers)
    match = re.search(test_status_pattern, line)
    groupdict = match.groupdict()
    for v in numeric_vars:
        groupdict[v] = float(groupdict[v])
    return groupdict


# extract params from executed notebooks
def extract_mechs_params(filename):
    with open(filename) as f:
        nb = json.load(f)
    # print(nb['cells'][2]['source'])
    exec('global mechanism_defs\nglobal extra_params\n' + ''.join(nb['cells'][2]['source']))
    return mechanism_defs, extra_params


test_results = []
for line in tests_ok + tests_error:
    result = parse_test_status_line(line)
    region_mechs = result['filename'][len('l5pc_validate_neuron_arbor_'):-len('.ipynb')].split('_')
    result['region'] = region_mechs[0]
    result['mechs_str'] = '_'.join(region_mechs[1:])
    
    mechs, params = extract_mechs_params(result['filename'])    
    result['mechs'] = mechs
    result['extra_params'] = extra_params
    test_results.append(result)

test_status_df = pandas.DataFrame(test_results)
regional_test_status = dict()

max_rows_default = pandas.options.display.max_rows
pandas.options.display.max_rows = None  # uncomment for full view
for region, regional_test_status_df in test_status_df.groupby(['region']):
    regional_test_status[region] = regional_test_status_df.sort_values(by='l1_norm', ascending=False)
    display(regional_test_status[region])
pandas.options.display.max_rows = max_rows_default
# Out:
#                                filename dt_setting     dt test_result  \
# 0  l5pc_validate_neuron_arbor_all.ipynb    Default  0.025          OK
# 1  l5pc_validate_neuron_arbor_all.ipynb       Fine  0.001          OK
#
#     l1_norm  l1_tol      l1_error  l1_error_tol region mechs_str  \
# 0  0.001010    0.05  1.700000e-08        0.0005    all
# 1  0.000381    0.05  2.130000e-08        0.0005    all
#
#               mechs                                       extra_params
# 0  {'all': ['pas']}  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 1  {'all': ['pas']}  {'v_init': 'global', 'celsius': 'global', 'g_p...
#                                              filename dt_setting     dt  \
# 22  l5pc_validate_neuron_arbor_apical_Im_SKv3_1_Na...    Default  0.025
# 24            l5pc_validate_neuron_arbor_apical.ipynb    Default  0.025
# 14  l5pc_validate_neuron_arbor_apical_Ih_SKv3_1_Na...    Default  0.025
# 30  l5pc_validate_neuron_arbor_apical_SKv3_1_NaTs2...    Default  0.025
# 4   l5pc_validate_neuron_arbor_apical_Ih_Im_NaTs2_...    Default  0.025
# 12  l5pc_validate_neuron_arbor_apical_Ih_SKv3_1.ipynb    Default  0.025
# 18  l5pc_validate_neuron_arbor_apical_Im_NaTs2_t.i...    Default  0.025
# 20  l5pc_validate_neuron_arbor_apical_Im_SKv3_1.ipynb    Default  0.025
# 28     l5pc_validate_neuron_arbor_apical_SKv3_1.ipynb    Default  0.025
# 6   l5pc_validate_neuron_arbor_apical_Ih_Im_SKv3_1...    Default  0.025
# 2       l5pc_validate_neuron_arbor_apical_Ih_Im.ipynb    Default  0.025
# 16         l5pc_validate_neuron_arbor_apical_Im.ipynb    Default  0.025
# 15  l5pc_validate_neuron_arbor_apical_Ih_SKv3_1_Na...       Fine  0.001
# 31  l5pc_validate_neuron_arbor_apical_SKv3_1_NaTs2...       Fine  0.001
# 23  l5pc_validate_neuron_arbor_apical_Im_SKv3_1_Na...       Fine  0.001
# 25            l5pc_validate_neuron_arbor_apical.ipynb       Fine  0.001
# 26    l5pc_validate_neuron_arbor_apical_NaTs2_t.ipynb    Default  0.025
# 10  l5pc_validate_neuron_arbor_apical_Ih_NaTs2_t.i...    Default  0.025
# 13  l5pc_validate_neuron_arbor_apical_Ih_SKv3_1.ipynb       Fine  0.001
# 29     l5pc_validate_neuron_arbor_apical_SKv3_1.ipynb       Fine  0.001
# 21  l5pc_validate_neuron_arbor_apical_Im_SKv3_1.ipynb       Fine  0.001
# 5   l5pc_validate_neuron_arbor_apical_Ih_Im_NaTs2_...       Fine  0.001
# 7   l5pc_validate_neuron_arbor_apical_Ih_Im_SKv3_1...       Fine  0.001
# 19  l5pc_validate_neuron_arbor_apical_Im_NaTs2_t.i...       Fine  0.001
# 8          l5pc_validate_neuron_arbor_apical_Ih.ipynb    Default  0.025
# 17         l5pc_validate_neuron_arbor_apical_Im.ipynb       Fine  0.001
# 3       l5pc_validate_neuron_arbor_apical_Ih_Im.ipynb       Fine  0.001
# 27    l5pc_validate_neuron_arbor_apical_NaTs2_t.ipynb       Fine  0.001
# 11  l5pc_validate_neuron_arbor_apical_Ih_NaTs2_t.i...       Fine  0.001
# 9          l5pc_validate_neuron_arbor_apical_Ih.ipynb       Fine  0.001
#
#    test_result   l1_norm  l1_tol      l1_error  l1_error_tol  region  \
# 22          OK  0.006470    0.05  1.470000e-07        0.0005  apical
# 24          OK  0.006460    0.05  1.330000e-07        0.0005  apical
# 14          OK  0.006070    0.05  8.470000e-07        0.0005  apical
# 30          OK  0.005880    0.05  5.060000e-07        0.0005  apical
# 4           OK  0.003790    0.05  2.300000e-07        0.0005  apical
# 12          OK  0.003790    0.05  4.290000e-07        0.0005  apical
# 18          OK  0.003740    0.05  2.250000e-07        0.0005  apical
# 20          OK  0.003570    0.05  7.500000e-08        0.0005  apical
# 28          OK  0.003560    0.05  3.700000e-07        0.0005  apical
# 6           OK  0.003500    0.05  3.450000e-07        0.0005  apical
# 2           OK  0.002750    0.05  6.490000e-08        0.0005  apical
# 16          OK  0.002730    0.05  1.220000e-07        0.0005  apical
# 15          OK  0.002430    0.05  3.550000e-04        0.0005  apical
# 31          OK  0.002360    0.05  2.090000e-06        0.0005  apical
# 23          OK  0.002110    0.05  1.840000e-06        0.0005  apical
# 25          OK  0.002100    0.05  1.110000e-05        0.0005  apical
# 26          OK  0.002080    0.05  2.460000e-08        0.0005  apical
# 10          OK  0.002010    0.05  1.700000e-08        0.0005  apical
# 13          OK  0.001350    0.05  4.080000e-06        0.0005  apical
# 29          OK  0.001160    0.05  6.340000e-06        0.0005  apical
# 21          OK  0.001120    0.05  1.820000e-06        0.0005  apical
# 5           OK  0.001040    0.05  6.510000e-06        0.0005  apical
# 7           OK  0.000982    0.05  1.700000e-06        0.0005  apical
# 19          OK  0.000958    0.05  9.190000e-07        0.0005  apical
# 8           OK  0.000932    0.05  1.410000e-08        0.0005  apical
# 17          OK  0.000622    0.05  5.980000e-07        0.0005  apical
# 3           OK  0.000598    0.05  8.770000e-07        0.0005  apical
# 27          OK  0.000533    0.05  3.010000e-08        0.0005  apical
# 11          OK  0.000456    0.05  6.740000e-08        0.0005  apical
# 9           OK  0.000425    0.05  1.140000e-08        0.0005  apical
#
#             mechs_str                                              mechs  \
# 22  Im_SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['Im', 'SKv3_1', 'N...
# 24                     {'all': ['pas'], 'apical': ['Ih', 'Im', 'SKv3_...
# 14  Ih_SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['Ih', 'SKv3_1', 'N...
# 30     SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['SKv3_1', 'NaTs2_t']}
# 4       Ih_Im_NaTs2_t  {'all': ['pas'], 'apical': ['Ih', 'Im', 'NaTs2...
# 12          Ih_SKv3_1       {'all': ['pas'], 'apical': ['Ih', 'SKv3_1']}
# 18         Im_NaTs2_t      {'all': ['pas'], 'apical': ['Im', 'NaTs2_t']}
# 20          Im_SKv3_1       {'all': ['pas'], 'apical': ['Im', 'SKv3_1']}
# 28             SKv3_1             {'all': ['pas'], 'apical': ['SKv3_1']}
# 6        Ih_Im_SKv3_1  {'all': ['pas'], 'apical': ['Ih', 'Im', 'SKv3_...
# 2               Ih_Im           {'all': ['pas'], 'apical': ['Ih', 'Im']}
# 16                 Im                 {'all': ['pas'], 'apical': ['Im']}
# 15  Ih_SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['Ih', 'SKv3_1', 'N...
# 31     SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['SKv3_1', 'NaTs2_t']}
# 23  Im_SKv3_1_NaTs2_t  {'all': ['pas'], 'apical': ['Im', 'SKv3_1', 'N...
# 25                     {'all': ['pas'], 'apical': ['Ih', 'Im', 'SKv3_...
# 26            NaTs2_t            {'all': ['pas'], 'apical': ['NaTs2_t']}
# 10         Ih_NaTs2_t      {'all': ['pas'], 'apical': ['Ih', 'NaTs2_t']}
# 13          Ih_SKv3_1       {'all': ['pas'], 'apical': ['Ih', 'SKv3_1']}
# 29             SKv3_1             {'all': ['pas'], 'apical': ['SKv3_1']}
# 21          Im_SKv3_1       {'all': ['pas'], 'apical': ['Im', 'SKv3_1']}
# 5       Ih_Im_NaTs2_t  {'all': ['pas'], 'apical': ['Ih', 'Im', 'NaTs2...
# 7        Ih_Im_SKv3_1  {'all': ['pas'], 'apical': ['Ih', 'Im', 'SKv3_...
# 19         Im_NaTs2_t      {'all': ['pas'], 'apical': ['Im', 'NaTs2_t']}
# 8                  Ih                 {'all': ['pas'], 'apical': ['Ih']}
# 17                 Im                 {'all': ['pas'], 'apical': ['Im']}
# 3               Ih_Im           {'all': ['pas'], 'apical': ['Ih', 'Im']}
# 27            NaTs2_t            {'all': ['pas'], 'apical': ['NaTs2_t']}
# 11         Ih_NaTs2_t      {'all': ['pas'], 'apical': ['Ih', 'NaTs2_t']}
# 9                  Ih                 {'all': ['pas'], 'apical': ['Ih']}
#
#                                          extra_params
# 22  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 24  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 14  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 30  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 4   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 12  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 18  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 20  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 28  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 6   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 2   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 16  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 15  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 31  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 23  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 25  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 26  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 10  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 13  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 29  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 21  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 5   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 7   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 19  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 8   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 17  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 3   {'v_init': 'global', 'celsius': 'global', 'g_p...
# 27  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 11  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 9   {'v_init': 'global', 'celsius': 'global', 'g_p...
#                                               filename dt_setting     dt  \
# 318  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 319  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 360      l5pc_validate_neuron_arbor_axonal_K_Tst.ipynb    Default  0.025
# 361      l5pc_validate_neuron_arbor_axonal_K_Tst.ipynb       Fine  0.001
# 372  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst....       Fine  0.001
# 371  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst....    Default  0.025
# 323  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 322  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 347  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...       Fine  0.001
# 346  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...    Default  0.025
# 351  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...       Fine  0.001
# 350  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...    Default  0.025
# 340  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...       Fine  0.001
# 339  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...    Default  0.025
# 334  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...       Fine  0.001
# 333  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...    Default  0.025
# 330  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...       Fine  0.001
# 329  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...    Default  0.025
# 341  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 342  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 367  l5pc_validate_neuron_arbor_axonal_K_Tst_NaTa_t...       Fine  0.001
# 321  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 366  l5pc_validate_neuron_arbor_axonal_K_Tst_NaTa_t...    Default  0.025
# 320  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 349  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...       Fine  0.001
# 348  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...    Default  0.025
# 374  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...       Fine  0.001
# 373  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...    Default  0.025
# 332  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...       Fine  0.001
# 331  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...    Default  0.025
# 377  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...    Default  0.025
# 337  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 385  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...    Default  0.025
# 382  l5pc_validate_neuron_arbor_axonal_SKv3_1_NaTa_...    Default  0.025
# 354  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 326  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 364  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_...    Default  0.025
# 365  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_...       Fine  0.001
# 376  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...    Default  0.025
# 362  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_...    Default  0.025
# 363  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst_...       Fine  0.001
# 370  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_...       Fine  0.001
# 369  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_...    Default  0.025
# 345  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...       Fine  0.001
# 316  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 317  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 358  l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et...    Default  0.025
# 359  l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et...       Fine  0.001
# 344  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...    Default  0.025
# 328  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...       Fine  0.001
# 327  l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...    Default  0.025
# 357  l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et...       Fine  0.001
# 356  l5pc_validate_neuron_arbor_axonal_K_Pst_Nap_Et...    Default  0.025
# 126  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...    Default  0.025
# 175  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_...    Default  0.025
# 158  l5pc_validate_neuron_arbor_axonal_K_Pst_NaTa_t...    Default  0.025
# 36   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 75   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...    Default  0.025
# 199  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...       Fine  0.001
# 355  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 62   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 200  l5pc_validate_neuron_arbor_axonal_SKv3_1_NaTa_...       Fine  0.001
# 386  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...       Fine  0.001
# 154            l5pc_validate_neuron_arbor_axonal.ipynb    Default  0.025
# 155            l5pc_validate_neuron_arbor_axonal.ipynb       Fine  0.001
# 190  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...    Default  0.025
# 191  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...       Fine  0.001
# 338  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 118  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 119  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 192  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...       Fine  0.001
# 93   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...    Default  0.025
# 87   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...    Default  0.025
# 94   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...       Fine  0.001
# 88   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...       Fine  0.001
# 128  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...    Default  0.025
# 129  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...       Fine  0.001
# 108  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...       Fine  0.001
# 107  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...    Default  0.025
# 37   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 176  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst_...       Fine  0.001
# 109  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...    Default  0.025
# 127  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...       Fine  0.001
# 177  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...    Default  0.025
# 159  l5pc_validate_neuron_arbor_axonal_K_Pst_NaTa_t...       Fine  0.001
# 38   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 103  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...    Default  0.025
# 77   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...    Default  0.025
# 178  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...       Fine  0.001
# 160  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst....    Default  0.025
# 76   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...       Fine  0.001
# 39   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 161  l5pc_validate_neuron_arbor_axonal_K_Tst_K_Pst....       Fine  0.001
# 78   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...       Fine  0.001
# 104  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...       Fine  0.001
# 140  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...    Default  0.025
# 110  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...       Fine  0.001
# 138  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...    Default  0.025
# 124  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...    Default  0.025
# 113  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 139  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...       Fine  0.001
# 141  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...       Fine  0.001
# 205  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...    Default  0.025
# 60   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 99   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 193  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...    Default  0.025
# 65   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...    Default  0.025
# 148  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 173  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst....    Default  0.025
# 73   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...    Default  0.025
# 50   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 34   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 89   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...    Default  0.025
# 156      l5pc_validate_neuron_arbor_axonal_K_Pst.ipynb    Default  0.025
# 114  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 125  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_P...       Fine  0.001
# 69   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...    Default  0.025
# 195  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...    Default  0.025
# 152  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 95   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 101  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 56   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 201  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...    Default  0.025
# 150  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 187     l5pc_validate_neuron_arbor_axonal_SKv3_1.ipynb    Default  0.025
# 63   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 188  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...    Default  0.025
# 97   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 58   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 203  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...    Default  0.025
# 144  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...    Default  0.025
# 66   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...       Fine  0.001
# 74   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Pst...       Fine  0.001
# 90   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...       Fine  0.001
# 174  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Pst....       Fine  0.001
# 51   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 131  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...       Fine  0.001
# 180  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...       Fine  0.001
# 41   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 165  l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et...       Fine  0.001
# 163  l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et...       Fine  0.001
# 40   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 35   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 130  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_K_T...    Default  0.025
# 164  l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et...    Default  0.025
# 162  l5pc_validate_neuron_arbor_axonal_K_Tst_Nap_Et...    Default  0.025
# 179  l5pc_validate_neuron_arbor_axonal_SK_E2_K_Tst_...    Default  0.025
# 80   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...       Fine  0.001
# 79   l5pc_validate_neuron_arbor_axonal_Ca_HVA_K_Tst...    Default  0.025
# 157      l5pc_validate_neuron_arbor_axonal_K_Pst.ipynb       Fine  0.001
# 146  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 120  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 145  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...       Fine  0.001
# 153  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 206  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...       Fine  0.001
# 61   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 196  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...       Fine  0.001
# 149  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 100  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 194  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...       Fine  0.001
# 151  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 189  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Pst...       Fine  0.001
# 98   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 59   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 204  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...       Fine  0.001
# 70   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...       Fine  0.001
# 197  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...    Default  0.025
# 198  l5pc_validate_neuron_arbor_axonal_SKv3_1_K_Tst...       Fine  0.001
# 96   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 57   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 102  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 46   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 169     l5pc_validate_neuron_arbor_axonal_NaTa_t.ipynb    Default  0.025
# 185  l5pc_validate_neuron_arbor_axonal_SK_E2_NaTa_t...    Default  0.025
# 375     l5pc_validate_neuron_arbor_axonal_SKv3_1.ipynb       Fine  0.001
# 202  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...       Fine  0.001
# 64   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 54   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 136  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_NaT...    Default  0.025
# 121  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 147  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 48   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 171      l5pc_validate_neuron_arbor_axonal_SK_E2.ipynb    Default  0.025
# 122   l5pc_validate_neuron_arbor_axonal_Ca_LVAst.ipynb    Default  0.025
# 32   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 116  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 85   l5pc_validate_neuron_arbor_axonal_Ca_HVA_NaTa_...    Default  0.025
# 111  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
# 71      l5pc_validate_neuron_arbor_axonal_Ca_HVA.ipynb    Default  0.025
# 55   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 186  l5pc_validate_neuron_arbor_axonal_SK_E2_NaTa_t...       Fine  0.001
# 137  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_NaT...       Fine  0.001
# 47   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 170     l5pc_validate_neuron_arbor_axonal_NaTa_t.ipynb       Fine  0.001
# 324  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 325  l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 49   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 380  l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_E...    Default  0.025
# 381  l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_E...       Fine  0.001
# 378  l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_E...    Default  0.025
# 379  l5pc_validate_neuron_arbor_axonal_SKv3_1_Nap_E...       Fine  0.001
# 383  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...    Default  0.025
# 384  l5pc_validate_neuron_arbor_axonal_SKv3_1_SK_E2...       Fine  0.001
# 172      l5pc_validate_neuron_arbor_axonal_SK_E2.ipynb       Fine  0.001
# 86   l5pc_validate_neuron_arbor_axonal_Ca_HVA_NaTa_...       Fine  0.001
# 117  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 33   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 352  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...    Default  0.025
# 123   l5pc_validate_neuron_arbor_axonal_Ca_LVAst.ipynb       Fine  0.001
# 353  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SKv...       Fine  0.001
# 68   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...       Fine  0.001
# 67   l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDyn...    Default  0.025
# 168  l5pc_validate_neuron_arbor_axonal_Nap_Et2_NaTa...       Fine  0.001
# 184  l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et...       Fine  0.001
# 84   l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_E...       Fine  0.001
# 45   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 335  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...    Default  0.025
# 135  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap...       Fine  0.001
# 167  l5pc_validate_neuron_arbor_axonal_Nap_Et2_NaTa...    Default  0.025
# 183  l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et...    Default  0.025
# 336  l5pc_validate_neuron_arbor_axonal_Ca_HVA_SKv3_...       Fine  0.001
# 83   l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_E...    Default  0.025
# 44   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 72      l5pc_validate_neuron_arbor_axonal_Ca_HVA.ipynb       Fine  0.001
# 134  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap...    Default  0.025
# 112  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 92   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...       Fine  0.001
# 43   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 91   l5pc_validate_neuron_arbor_axonal_Ca_HVA_SK_E2...    Default  0.025
# 368    l5pc_validate_neuron_arbor_axonal_Nap_Et2.ipynb       Fine  0.001
# 53   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...       Fine  0.001
# 182  l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et...       Fine  0.001
# 42   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 82   l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_E...       Fine  0.001
# 106  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...       Fine  0.001
# 181  l5pc_validate_neuron_arbor_axonal_SK_E2_Nap_Et...    Default  0.025
# 52   l5pc_validate_neuron_arbor_axonal_CaDynamics_E...    Default  0.025
# 166    l5pc_validate_neuron_arbor_axonal_Nap_Et2.ipynb    Default  0.025
# 143  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...       Fine  0.001
# 133  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap...       Fine  0.001
# 343  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...       Fine  0.001
# 81   l5pc_validate_neuron_arbor_axonal_Ca_HVA_Nap_E...    Default  0.025
# 105  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaD...    Default  0.025
# 142  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_SK_...    Default  0.025
# 132  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Nap...    Default  0.025
# 115  l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_...    Default  0.025
#
#     test_result   l1_norm  l1_tol      l1_error  l1_error_tol  region  \
# 318       ERROR  0.687000    0.05  2.860000e-08        0.0005  axonal
# 319       ERROR  0.687000    0.05  2.850000e-08        0.0005  axonal
# 360       ERROR  0.687000    0.05  2.830000e-08        0.0005  axonal
# 361       ERROR  0.687000    0.05  2.620000e-08        0.0005  axonal
# 372       ERROR  0.681000    0.05  2.140000e-08        0.0005  axonal
# 371       ERROR  0.681000    0.05  1.780000e-08        0.0005  axonal
# 323       ERROR  0.678000    0.05  2.260000e-08        0.0005  axonal
# 322       ERROR  0.677000    0.05  1.720000e-08        0.0005  axonal
# 347       ERROR  0.674000    0.05  3.990000e-08        0.0005  axonal
# 346       ERROR  0.674000    0.05  3.950000e-08        0.0005  axonal
# 351       ERROR  0.669000    0.05  2.770000e-08        0.0005  axonal
# 350       ERROR  0.669000    0.05  2.660000e-08        0.0005  axonal
# 340       ERROR  0.668000    0.05  2.230000e-08        0.0005  axonal
# 339       ERROR  0.667000    0.05  2.740000e-08        0.0005  axonal
# 334       ERROR  0.610000    0.05  1.620000e-08        0.0005  axonal
# 333       ERROR  0.610000    0.05  1.770000e-08        0.0005  axonal
# 319             CaDynamics_E2_K_Tst
# 360                           K_Tst
# 361                           K_Tst
# 372                     SK_E2_K_Tst
# 371                     SK_E2_K_Tst
# 323       CaDynamics_E2_SK_E2_K_Tst
# 322       CaDynamics_E2_SK_E2_K_Tst
# 347                  Ca_LVAst_K_Tst
# 346                  Ca_LVAst_K_Tst
# 351            Ca_LVAst_SK_E2_K_Tst
# 350            Ca_LVAst_SK_E2_K_Tst
# 340    Ca_LVAst_CaDynamics_E2_K_Tst
# 339    Ca_LVAst_CaDynamics_E2_K_Tst
# 334              Ca_HVA_SK_E2_K_Tst
# 333              Ca_HVA_SK_E2_K_Tst
# 330                    Ca_HVA_K_Tst
# 329                    Ca_HVA_K_Tst
# 341           Ca_LVAst_Ca_HVA_K_Tst
# 342           Ca_LVAst_Ca_HVA_K_Tst
# 367                    K_Tst_NaTa_t
# 321      CaDynamics_E2_K_Tst_NaTa_t
# 366                    K_Tst_NaTa_t
# 320      CaDynamics_E2_K_Tst_NaTa_t
# 349           Ca_LVAst_K_Tst_NaTa_t
# 348           Ca_LVAst_K_Tst_NaTa_t
# 374              SK_E2_K_Tst_NaTa_t
# 373              SK_E2_K_Tst_NaTa_t
# 332             Ca_HVA_K_Tst_NaTa_t
# 331             Ca_HVA_K_Tst_NaTa_t
# 377             SKv3_1_K_Tst_NaTa_t
# 337            Ca_HVA_SKv3_1_NaTa_t
# 385             SKv3_1_SK_E2_NaTa_t
# 382                   SKv3_1_NaTa_t
# 354          Ca_LVAst_SKv3_1_NaTa_t
# 326     CaDynamics_E2_SKv3_1_NaTa_t
# 364              K_Tst_K_Pst_NaTa_t
# 365              K_Tst_K_Pst_NaTa_t
# 376             SKv3_1_K_Pst_NaTa_t
# 362             K_Tst_K_Pst_Nap_Et2
# 363             K_Tst_K_Pst_Nap_Et2
# 370             SK_E2_K_Pst_Nap_Et2
# 369             SK_E2_K_Pst_Nap_Et2
# 345          Ca_LVAst_K_Pst_Nap_Et2
# 316     CaDynamics_E2_K_Pst_Nap_Et2
# 317     CaDynamics_E2_K_Pst_Nap_Et2
# 358            K_Pst_Nap_Et2_NaTa_t
# ...
# 304                         SKv3_1
# 312                SKv3_1_SK_E2_Ih
# 302                      SKv3_1_Ih
# 306     SKv3_1_SK_E2_CaDynamics_E2
# 308            SKv3_1_SK_E2_Ca_HVA
# 285    SKv3_1_CaDynamics_E2_Ca_HVA
# 311          SKv3_1_SK_E2_Ca_LVAst
# 298             SKv3_1_Ca_LVAst_Ih
# 292         SKv3_1_Ca_HVA_Ca_LVAst
# 300                SKv3_1_Ca_LVAst
# 309            SKv3_1_SK_E2_Ca_HVA
# 245                        NaTs2_t
# 253               NaTs2_t_SK_E2_Ih
# 229       NaTs2_t_CaDynamics_E2_Ih
# 231          NaTs2_t_CaDynamics_E2
# 243                     NaTs2_t_Ih
# 247    NaTs2_t_SK_E2_CaDynamics_E2
# 255                  NaTs2_t_SK_E2
# 295               SKv3_1_Ca_HVA_Ih
# 289        SKv3_1_CaDynamics_E2_Ih
# 239            NaTs2_t_Ca_LVAst_Ih
# 297                  SKv3_1_Ca_HVA
# 291           SKv3_1_CaDynamics_E2
# 303                      SKv3_1_Ih
# 313                SKv3_1_SK_E2_Ih
# 315                   SKv3_1_SK_E2
# 241               NaTs2_t_Ca_LVAst
# 307     SKv3_1_SK_E2_CaDynamics_E2
# 305                         SKv3_1
# 268            SK_E2_CaDynamics_E2
# 221                    Ca_LVAst_Ih
# 266         SK_E2_CaDynamics_E2_Ih
# 223                       Ca_LVAst
# 282                          SK_E2
# 225                             Ih
# 293         SKv3_1_Ca_HVA_Ca_LVAst
# 280                       SK_E2_Ih
# 209               CaDynamics_E2_Ih
# 211                  CaDynamics_E2
# 299             SKv3_1_Ca_LVAst_Ih
# 301                SKv3_1_Ca_LVAst
# 235              NaTs2_t_Ca_HVA_Ih
# 237                 NaTs2_t_Ca_HVA
# 233        NaTs2_t_Ca_HVA_Ca_LVAst
# 215                Ca_HVA_Ca_LVAst
# 213             Ca_HVA_Ca_LVAst_Ih
# 217                      Ca_HVA_Ih
# 219                         Ca_HVA
# 230       NaTs2_t_CaDynamics_E2_Ih
# 244                     NaTs2_t_Ih
# 248    NaTs2_t_SK_E2_CaDynamics_E2
# 246                        NaTs2_t
# 240            NaTs2_t_Ca_LVAst_Ih
# 256                  NaTs2_t_SK_E2
# 254               NaTs2_t_SK_E2_Ih
# 232          NaTs2_t_CaDynamics_E2
# 242               NaTs2_t_Ca_LVAst
# 269            SK_E2_CaDynamics_E2
# 226                             Ih
# 283                          SK_E2
# 210               CaDynamics_E2_Ih
# 267         SK_E2_CaDynamics_E2_Ih
# 212                  CaDynamics_E2
# 281                       SK_E2_Ih
# 224                       Ca_LVAst
# 222                    Ca_LVAst_Ih
# 238                 NaTs2_t_Ca_HVA
# 234        NaTs2_t_Ca_HVA_Ca_LVAst
# 236              NaTs2_t_Ca_HVA_Ih
# 214             Ca_HVA_Ca_LVAst_Ih
# 220                         Ca_HVA
# 216                Ca_HVA_Ca_LVAst
# 218                      Ca_HVA_Ih
#
#                                                  mechs  \
# 388  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 392  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 391  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 387  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 390  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 389  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 270  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA'...
# 271  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA'...
# 274   {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA']}
# 272  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA'...
# 249  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 275   {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA']}
# 273  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_HVA'...
# 250  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 265  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 264  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 227  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 286  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 261  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 258  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 257  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 260  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 287  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 393  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 259  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 263  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 262  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 278  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_LVAs...
# 276  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_LVAs...
# 279  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_LVAs...
# 277  {'all': ['pas'], 'somatic': ['SK_E2', 'Ca_LVAs...
# 251  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 252  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 284  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 228  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SKv3_...
# 310  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 294  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA...
# 290  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 296  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA']}
# 314   {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2']}
# 288  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 304            {'all': ['pas'], 'somatic': ['SKv3_1']}
# 312  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 302      {'all': ['pas'], 'somatic': ['SKv3_1', 'Ih']}
# 306  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 308  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 285  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 311  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 298  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_LVA...
# 292  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA...
# 300  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_LVA...
# 309  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 245           {'all': ['pas'], 'somatic': ['NaTs2_t']}
# 253  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 229  {'all': ['pas'], 'somatic': ['NaTs2_t', 'CaDyn...
# 231  {'all': ['pas'], 'somatic': ['NaTs2_t', 'CaDyn...
# 243     {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ih']}
# 247  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 255  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2']}
# 295  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA...
# 289  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 239  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_LV...
# 297  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA']}
# 291  {'all': ['pas'], 'somatic': ['SKv3_1', 'CaDyna...
# 303      {'all': ['pas'], 'somatic': ['SKv3_1', 'Ih']}
# 313  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 315   {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2']}
# 241  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_LV...
# 307  {'all': ['pas'], 'somatic': ['SKv3_1', 'SK_E2'...
# 305            {'all': ['pas'], 'somatic': ['SKv3_1']}
# 268  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 221    {'all': ['pas'], 'somatic': ['Ca_LVAst', 'Ih']}
# 266  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 223          {'all': ['pas'], 'somatic': ['Ca_LVAst']}
# 282             {'all': ['pas'], 'somatic': ['SK_E2']}
# 225                {'all': ['pas'], 'somatic': ['Ih']}
# 293  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_HVA...
# 280       {'all': ['pas'], 'somatic': ['SK_E2', 'Ih']}
# 209  {'all': ['pas'], 'somatic': ['CaDynamics_E2', ...
# 211     {'all': ['pas'], 'somatic': ['CaDynamics_E2']}
# 299  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_LVA...
# 301  {'all': ['pas'], 'somatic': ['SKv3_1', 'Ca_LVA...
# 235  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 237  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 233  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 215  {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ca_LVA...
# 213  {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ca_LVA...
# 217      {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ih']}
# 219            {'all': ['pas'], 'somatic': ['Ca_HVA']}
# 230  {'all': ['pas'], 'somatic': ['NaTs2_t', 'CaDyn...
# 244     {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ih']}
# 248  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 246           {'all': ['pas'], 'somatic': ['NaTs2_t']}
# 240  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_LV...
# 256  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2']}
# 254  {'all': ['pas'], 'somatic': ['NaTs2_t', 'SK_E2...
# 232  {'all': ['pas'], 'somatic': ['NaTs2_t', 'CaDyn...
# 242  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_LV...
# 269  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 226                {'all': ['pas'], 'somatic': ['Ih']}
# 283             {'all': ['pas'], 'somatic': ['SK_E2']}
# 210  {'all': ['pas'], 'somatic': ['CaDynamics_E2', ...
# 267  {'all': ['pas'], 'somatic': ['SK_E2', 'CaDynam...
# 212     {'all': ['pas'], 'somatic': ['CaDynamics_E2']}
# 281       {'all': ['pas'], 'somatic': ['SK_E2', 'Ih']}
# 224          {'all': ['pas'], 'somatic': ['Ca_LVAst']}
# 222    {'all': ['pas'], 'somatic': ['Ca_LVAst', 'Ih']}
# 238  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 234  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 236  {'all': ['pas'], 'somatic': ['NaTs2_t', 'Ca_HV...
# 214  {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ca_LVA...
# 220            {'all': ['pas'], 'somatic': ['Ca_HVA']}
# 216  {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ca_LVA...
# 218      {'all': ['pas'], 'somatic': ['Ca_HVA', 'Ih']}
#
#                                           extra_params
# 388  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 392  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 391  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 387  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 390  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 389  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 270  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 271  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 274  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 272  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 249  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 275  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 273  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 250  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 265  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 264  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 227  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 286  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 261  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 258  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 257  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 260  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 287  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 393  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 259  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 263  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 262  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 278  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 276  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 279  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 277  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 251  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 252  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 284  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 228  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 310  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 294  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 290  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 296  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 314  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 288  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 304  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 312  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 302  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 306  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 308  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 285  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 311  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 298  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 292  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 300  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 309  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 245  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 253  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 229  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 231  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 243  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 247  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 255  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 295  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 289  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 239  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 297  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 291  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 303  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 313  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 315  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 241  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 307  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 305  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 268  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 221  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 266  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 223  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 282  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 225  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 293  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 280  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 209  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 211  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 299  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 301  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 235  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 237  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 233  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 215  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 213  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 217  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 219  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 230  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 244  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 248  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 246  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 240  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 256  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 254  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 232  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 242  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 269  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 226  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 283  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 210  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 267  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 212  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 281  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 224  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 222  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 238  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 234  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 236  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 214  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 220  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 216  {'v_init': 'global', 'celsius': 'global', 'g_p...
# 218  {'v_init': 'global', 'celsius': 'global', 'g_p...

# %% [markdown]
# We can rank-order the mechs w.r.t. the L1-deviation on each region and for each `dt` configuration.

# %%
def regional_rank_stats(region, regional_test_status):
    regional_mechs = regional_test_status[regional_test_status['mechs_str'] == ''].iloc[0]['mechs'][region]
    regional_mech_ranks = {dt_setting: [] for dt_setting in regional_test_status_df['dt_setting'].unique()}
    for mech in regional_mechs:
        for dt_setting, dt_group in regional_test_status_df.groupby('dt_setting'):
            regional_mech_ranks[dt_setting].append(dict(region=region, dt_setting=dt_setting, mech=mech))
            rank_stats = 1./len(dt_group)*dt_group['l1_norm'].rank(ascending=False)[ dt_group.apply(lambda r: mech in r['mechs_str'], axis=1) ].describe()
            for k, v in rank_stats.items():
                regional_mech_ranks[dt_setting][-1]['rank_' + k] = v
    return {dt_setting: pandas.DataFrame(dt_group).sort_values(by='rank_mean') for dt_setting, dt_group in regional_mech_ranks.items()}

mech_rank_stats = dict()
for region, regional_test_status_df in regional_test_status.items():
    mech_rank_stats[region] = dict()
    for dt_setting, rank_stats in regional_rank_stats(region, regional_test_status[region]).items():
        mech_rank_stats[region][dt_setting] = rank_stats
        display(rank_stats)
# Out:
#   region dt_setting mech  rank_count  rank_mean  rank_std  rank_min  rank_25%  \
# 0    all    Default  pas         0.0        NaN       NaN       NaN       NaN
#
#    rank_50%  rank_75%  rank_max
# 0       NaN       NaN       NaN
#   region dt_setting mech  rank_count  rank_mean  rank_std  rank_min  rank_25%  \
# 0    all       Fine  pas         0.0        NaN       NaN       NaN       NaN
#
#    rank_50%  rank_75%  rank_max
# 0       NaN       NaN       NaN
#    region dt_setting     mech  rank_count  rank_mean  rank_std  rank_min  \
# 2  apical    Default   SKv3_1    0.466667   0.385714  0.222658  0.066667
# 3  apical    Default  NaTs2_t    0.466667   0.452381  0.331024  0.066667
# 1  apical    Default       Im    0.466667   0.519048  0.250819  0.066667
# 0  apical    Default       Ih    0.466667   0.609524  0.305938  0.200000
#
#    rank_25%  rank_50%  rank_75%  rank_max
# 2  0.233333  0.366667  0.566667  0.666667
# 3  0.233333  0.366667  0.666667  0.933333
# 1  0.416667  0.533333  0.700000  0.800000
# 0  0.366667  0.666667  0.833333  1.000000
#    region dt_setting     mech  rank_count  rank_mean  rank_std  rank_min  \
# 2  apical       Fine   SKv3_1    0.466667   0.314286  0.191347  0.066667
# 3  apical       Fine  NaTs2_t    0.466667   0.485714  0.356348  0.066667
# 1  apical       Fine       Im    0.466667   0.571429  0.199470  0.200000
# 0  apical       Fine       Ih    0.466667   0.609524  0.334284  0.066667
#
#    rank_25%  rank_50%  rank_75%  rank_max
# 2  0.166667  0.333333  0.433333  0.600000
# 3  0.166667  0.533333  0.766667  0.933333
# 1  0.500000  0.600000  0.700000  0.800000
# 0  0.433333  0.600000  0.866667  1.000000
#    region dt_setting           mech  rank_count  rank_mean  rank_std  \
# 5  axonal    Default          K_Tst    0.292683   0.303749  0.247281
# 6  axonal    Default          K_Pst    0.300813   0.376840  0.139128
# 8  axonal    Default         NaTa_t    0.284553   0.446574  0.318021
# 4  axonal    Default          SK_E2    0.292683   0.502371  0.286757
# 0  axonal    Default       Ca_LVAst    0.276423   0.515423  0.304946
# 3  axonal    Default         SKv3_1    0.300813   0.522962  0.227695
# 2  axonal    Default  CaDynamics_E2    0.243902   0.523171  0.293105
# 1  axonal    Default         Ca_HVA    0.260163   0.534553  0.289467
# 7  axonal    Default        Nap_Et2    0.300813   0.721600  0.280762
#
#    rank_min  rank_25%  rank_50%  rank_75%  rank_max
# 5  0.012195  0.079268  0.264228  0.475610  0.715447
# 6  0.178862  0.252033  0.382114  0.483740  0.634146
# 8  0.093496  0.158537  0.272358  0.752033  0.918699
# 4  0.024390  0.315041  0.504065  0.742886  0.983740
# 0  0.040650  0.315041  0.447154  0.773374  1.000000
# 3  0.130081  0.430894  0.565041  0.634146  0.878049
# 2  0.012195  0.343496  0.516260  0.761179  0.975610
# 1  0.065041  0.315041  0.520325  0.806911  1.000000
# 7  0.195122  0.666667  0.853659  0.926829  1.000000
#    region dt_setting           mech  rank_count  rank_mean  rank_std  \
# 5  axonal       Fine          K_Tst    0.292683   0.284327  0.222314
# 6  axonal       Fine          K_Pst    0.300813   0.369809  0.151142
# 8  axonal       Fine         NaTa_t    0.284553   0.452962  0.295256
# 4  axonal       Fine          SK_E2    0.292683   0.498419  0.288634
# 0  axonal       Fine       Ca_LVAst    0.276423   0.513749  0.309032
# 2  axonal       Fine  CaDynamics_E2    0.243902   0.528184  0.292714
# 1  axonal       Fine         Ca_HVA    0.260163   0.545224  0.298648
# 3  axonal       Fine         SKv3_1    0.300813   0.566249  0.202723
# 7  axonal       Fine        Nap_Et2    0.300813   0.668864  0.308547
#
#    rank_min  rank_25%  rank_50%  rank_75%  rank_max
# 5  0.012195  0.079268  0.243902  0.487805  0.650407
# 6  0.130081  0.268293  0.361789  0.455285  0.634146
# 8  0.093496  0.207317  0.325203  0.752033  0.894309
# 4  0.024390  0.280488  0.475610  0.725610  0.987805
# 0  0.040650  0.294715  0.455285  0.800813  1.000000
# 2  0.012195  0.322154  0.536585  0.760163  0.975610
# 1  0.065041  0.280488  0.554878  0.829268  1.000000
# 3  0.195122  0.544715  0.617886  0.691057  0.902439
# 7  0.138211  0.487805  0.796748  0.926829  1.000000
#   region dt_setting mech  rank_count  rank_mean  rank_std  rank_min  rank_25%  \
# 0  basal    Default   Ih         0.0        NaN       NaN       NaN       NaN
#
#    rank_50%  rank_75%  rank_max
# 0       NaN       NaN       NaN
#   region dt_setting mech  rank_count  rank_mean  rank_std  rank_min  rank_25%  \
# 0  basal       Fine   Ih         0.0        NaN       NaN       NaN       NaN
#
#    rank_50%  rank_75%  rank_max
# 0       NaN       NaN       NaN
#     region dt_setting           mech  rank_count  rank_mean  rank_std  \
# 1  somatic    Default         SKv3_1    0.385965   0.326156  0.184014
# 2  somatic    Default          SK_E2    0.385965   0.418660  0.250681
# 0  somatic    Default        NaTs2_t    0.350877   0.471053  0.325889
# 3  somatic    Default  CaDynamics_E2    0.263158   0.500000  0.258990
# 5  somatic    Default       Ca_LVAst    0.315789   0.514620  0.295041
# 4  somatic    Default         Ca_HVA    0.315789   0.533626  0.363738
# 6  somatic    Default             Ih    0.350877   0.610965  0.261897
#
#    rank_min  rank_25%  rank_50%  rank_75%  rank_max
# 1  0.017544  0.135965  0.372807  0.469298  0.561404
# 2  0.035088  0.206140  0.368421  0.655702  0.842105
# 0  0.017544  0.100877  0.605263  0.682018  0.929825
# 3  0.070175  0.280702  0.491228  0.706140  0.877193
# 5  0.105263  0.267544  0.535088  0.745614  0.964912
# 4  0.017544  0.192982  0.447368  0.925439  1.000000
# 6  0.087719  0.449561  0.631579  0.828947  0.982456
#     region dt_setting           mech  rank_count  rank_mean  rank_std  \
# 1  somatic       Fine         SKv3_1    0.385965   0.349282  0.149690
# 2  somatic       Fine          SK_E2    0.385965   0.394737  0.273790
# 3  somatic       Fine  CaDynamics_E2    0.263158   0.487719  0.256383
# 0  somatic       Fine        NaTs2_t    0.350877   0.492544  0.298141
# 4  somatic       Fine         Ca_HVA    0.315789   0.507310  0.386448
# 5  somatic       Fine       Ca_LVAst    0.315789   0.510721  0.319474
# 6  somatic       Fine             Ih    0.350877   0.605702  0.271870
#
#    rank_min  rank_25%  rank_50%  rank_75%  rank_max
# 1  0.105263  0.190789  0.377193  0.469298  0.561404
# 2  0.017544  0.195175  0.337719  0.653509  0.842105
# 3  0.087719  0.276316  0.491228  0.719298  0.824561
# 0  0.070175  0.177632  0.605263  0.688596  0.929825
# 4  0.017544  0.149123  0.385965  0.925439  1.000000
# 5  0.017544  0.250000  0.535088  0.824561  0.982456
# 6  0.043860  0.425439  0.622807  0.815789  1.000000

# %% [markdown]
# Plotting the relative L1-deviation between Arbor and Neuron. The x-labels indicate the used mechanisms from the region (if missing, all regional mechanisms are used).

# %%
fig, axs = plt.subplots(len(regional_test_status), 1, sharey=True, figsize=(25, 6*len(regional_test_status)))

def show_test_status(ax, region, test_status_df, extra_label=''):
    for dt_setting, dt_group in test_status_df.groupby('dt_setting'):
        ax.errorbar(dt_group['mechs_str'],
                    dt_group['l1_norm'], yerr=dt_group['l1_error'], fmt='o', label= region + '/' + dt_setting + ' dt' + extra_label)
    ax.tick_params(axis='x', labelrotation=90)
    ax.tick_params(labelright=True)
    ax.set_yscale('log')
    ax.yaxis.set_major_formatter(plt.FormatStrFormatter("%.2g"))
    ax.grid(visible=True, which='both', axis='y', alpha=0.5)
    ax.set_ylabel('Relative L1-norm Arbor-Neuron')
    ax.set_xlim(-0.5,len(dt_group)-0.5)
    ax.legend()
    

for i, (region, regional_test_status_df) in enumerate(regional_test_status.items()):
    show_test_status(axs[i], region, regional_test_status_df)
fig.tight_layout()
plt.show()

# %% [markdown]
# Repeating these plots on `axonal` and `somatic` regions for only the combinations with the highest-ranked mechanisms helps to get a better overview.

# %%
fig, axs = plt.subplots(4, 1, sharey=True, figsize=(12.5, 6*4))

mech_rank_stats['axonal']['Fine']['mech'].head(2)
mech_rank_stats['somatic']['Fine']['mech'].head(2)

i = 0
for region in ['axonal', 'somatic']:
    for mech in mech_rank_stats[region]['Fine']['mech'].head(2):
        show_test_status(axs[i],
                         region,
                         regional_test_status[region][regional_test_status[region]['mechs'].apply(lambda mechs: mech in mechs[region])],
                         ' (' + mech + ' only)')
        i += 1
        
fig.tight_layout()
plt.show()

# %% [markdown]
# Tests with N/A result obtained above:

# %%
# %%bash
#
# cat tests_na
# Out:
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst_Ih.ipynb
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb

# %% [markdown]
# Usually this is due to failing to advance time-integration in NEURON. Printing all other cases here.

# %%
# %%bash
#
# for f in $(cat tests_na); do
#     if ! grep NEURON:\ variable\ step\ integrator\ error $f > /dev/null; then
#          echo $f
#     fi
# done

# %% [markdown]
# The error messages contain more info.

# %%
# %%bash
#
# grep -C 1 CVode $(cat tests_na)
# Out:
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 59.0538 and h = 2.94441e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 82.6423 and h = 1.47772e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 54.1259 and h = 1.26325e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 56.004 and h = 3.48443e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 82.8669 and h = 1.77259e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 54.6592 and h = 1.80582e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 80.7109 and h = 1.62365e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 53.6685 and h = 1.02002e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 71.8872 and h = 2.85529e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 66.2304 and h = 1.56778e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 69.9623 and h = 4.93023e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 66.8829 and h = 1.99854e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x4353540 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 65.5175 and h = 1.368e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "exp(1293.55) out of range, returning exp(700)\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 66.8356 and h = 2.60407e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "exp(1155.3) out of range, returning exp(700)\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 62.1485 and h = 3.61252e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 72.5351 and h = 2.90459e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "exp(2547.86) out of range, returning exp(700)\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 78.4908 and h = 2.0394e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 97.0588 and h = 9.18214e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 74.6052 and h = 1.83462e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 74.5169 and h = 4.69721e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 84.2699 and h = 3.18639e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode 0x2acd920 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb:      "CVode-- At t = 90.0839 and h = 2.14918e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_K_Tst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 114.843 and h = 4.28386e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 72.2548 and h = 1.81751e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 51.3839 and h = 1.39016e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 83.9404 and h = 4.10205e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 53.4355 and h = 3.79411e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 83.2191 and h = 4.32342e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 54.2751 and h = 2.34158e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 87.523 and h = 1.95408e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 56.1599 and h = 2.73105e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 60.9235 and h = 1.74237e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 64.2669 and h = 1.06417e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 61.9923 and h = 2.62039e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x300c100 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 67.2528 and h = 2.87197e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb:      "CVode 0x398c590 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb:      "CVode-- At t = 59.2966 and h = 2.7387e-06, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_HVA_CaDynamics_E2_SK_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode 0x37d92e0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode-- At t = 55.4442 and h = 4.75879e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode 0x37d92e0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode-- At t = 54.9088 and h = 1.55813e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode 0x37d92e0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb:      "CVode-- At t = 54.3772 and h = 1.93771e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x40ff1d0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 50.9809 and h = 1.49452e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb:      "CVode 0x40ff1d0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb:      "CVode-- At t = 63.1002 and h = 1.13894e-07, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_CaDynamics_E2_NaTa_t.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 112.135 and h = 3.32664e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 81.1054 and h = 1.65467e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 53.8569 and h = 2.36011e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 55.9852 and h = 3.39963e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 83.3265 and h = 3.33776e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 54.324 and h = 2.88602e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "exp(798.014) out of range, returning exp(700)\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 79.5338 and h = 2.18522e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 53.467 and h = 1.85244e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 72.0462 and h = 3.13928e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 66.4453 and h = 2.73009e-08, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 70.3225 and h = 4.74507e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 67.5629 and h = 4.44997e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode 0x445c660 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-     "text": [
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb:      "CVode-- At t = 65.094 and h = 1.66017e-09, the corrector\n",
# l5pc_validate_neuron_arbor_axonal_Ca_LVAst_Ca_HVA_CaDynamics_E2.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 80.8578 and h = 1.4756e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 53.7464 and h = 1.43202e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 86.5036 and h = 5.89396e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 54.6872 and h = 6.10243e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 80.0003 and h = 1.82601e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 53.6827 and h = 4.13234e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 55.6137 and h = 3.92429e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 81.6319 and h = 2.04401e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 54.1016 and h = 1.72414e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 66.0535 and h = 1.37432e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 68.1507 and h = 5.8641e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 65.6874 and h = 1.05044e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 69.5873 and h = 5.88365e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode 0x40ea840 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb:      "CVode-- At t = 65.7754 and h = 2.83208e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode 0x35ebce0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode-- At t = 80.7964 and h = 1.76887e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode 0x35ebce0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode-- At t = 53.855 and h = 1.10829e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode 0x35ebce0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode-- At t = 85.4128 and h = 6.08915e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode 0x35ebce0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode-- At t = 54.9692 and h = 2.49584e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode 0x35ebce0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_HVA_Ih.ipynb:      "CVode-- At t = 80.4166 and h = 6.82155e-09, the corrector\n",
# ...
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 53.8066 and h = 1.10896e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x40351d0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 56.2129 and h = 1.48808e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x40351d0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 55.8471 and h = 3.97226e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 73.3874 and h = 1.87199e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 51.6795 and h = 1.79408e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 78.2247 and h = 4.52242e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 53.0301 and h = 2.4509e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 73.5565 and h = 6.88664e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 51.129 and h = 6.86546e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 80.2801 and h = 1.24895e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 52.9983 and h = 6.51234e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 75.2089 and h = 2.17455e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 52.4625 and h = 2.33943e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 60.5836 and h = 2.12628e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 64.0686 and h = 3.13481e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 60.5596 and h = 7.15245e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 63.5358 and h = 6.02652e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode 0x35a5910 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb:      "CVode-- At t = 61.2789 and h = 3.13104e-09, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_HVA.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 51.7624 and h = 1.06273e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 53.3662 and h = 1.85586e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 51.2447 and h = 1.18497e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 53.601 and h = 1.07366e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 52.3403 and h = 2.63854e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     "text": [
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode 0x43580a0 simple_cell[0].soma[0] advance_tn failed, err=-7.\n"
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-     ]
# --
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "No more errno warnings during this execution\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb:      "CVode-- At t = 61.8665 and h = 5.39345e-08, the corrector\n",
# l5pc_validate_neuron_arbor_somatic_NaTs2_t_CaDynamics_E2_Ca_LVAst.ipynb-      "convergence failed repeatedly or with |h| = hmin.\n",
